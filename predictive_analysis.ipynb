# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/daily-total-female-births-CA.xls')

# %%
df.head()
# Out:
#          date  births
# 0  1959-01-01      35
# 1  1959-01-02      32
# 2  1959-01-03      30
# 3  1959-01-04      31
# 4  1959-01-05      44

# %%
df['date'].dtypes
# Out:
# dtype('O')

# %%
df2 = pd.read_csv('/content/daily-total-female-births-CA.xls',header=0,parse_dates=[0])

# %%
df2.head()
# Out:
#         date  births
# 0 1959-01-01      35
# 1 1959-01-02      32
# 2 1959-01-03      30
# 3 1959-01-04      31
# 4 1959-01-05      44

# %%
df2['date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
series=pd.read_csv('/content/daily-total-female-births-CA.xls',header=0,parse_dates=[0],index_col=0).squeeze("columns")

# %%
series.head()
# Out:
# date
# 1959-01-01    35
# 1959-01-02    32
# 1959-01-03    30
# 1959-01-04    31
# 1959-01-05    44
# Name: births, dtype: int64

# %%
series.shape
# Out:
# (365,)

# %%
df2.shape
# Out:
# (365, 2)

# %%
print(series['1959-01'])
# Out:
# date
# 1959-01-01    35
# 1959-01-02    32
# 1959-01-03    30
# 1959-01-04    31
# 1959-01-05    44
# 1959-01-06    29
# 1959-01-07    45
# 1959-01-08    43
# 1959-01-09    38
# 1959-01-10    27
# 1959-01-11    38
# 1959-01-12    33
# 1959-01-13    55
# 1959-01-14    47
# 1959-01-15    45
# 1959-01-16    37
# 1959-01-17    50
# 1959-01-18    43
# 1959-01-19    41
# 1959-01-20    52
# 1959-01-21    34
# 1959-01-22    53
# 1959-01-23    39
# 1959-01-24    32
# 1959-01-25    37
# 1959-01-26    43
# 1959-01-27    39
# 1959-01-28    35
# 1959-01-29    44
# 1959-01-30    38
# 1959-01-31    24
# Name: births, dtype: int64

# %%
df2[(df2['date']>'1959-01-01') & (df2['date'] <= '1959-01-21')]
# Out:
#          date  births
# 1  1959-01-02      32
# 2  1959-01-03      30
# 3  1959-01-04      31
# 4  1959-01-05      44
# 5  1959-01-06      29
# 6  1959-01-07      45
# 7  1959-01-08      43
# 8  1959-01-09      38
# 9  1959-01-10      27
# 10 1959-01-11      38
# 11 1959-01-12      33
# 12 1959-01-13      55
# 13 1959-01-14      47
# 14 1959-01-15      45
# 15 1959-01-16      37
# 16 1959-01-17      50
# 17 1959-01-18      43
# 18 1959-01-19      41
# 19 1959-01-20      52
# 20 1959-01-21      34

# %%
series.describe()
# Out:
# count    365.000000
# mean      41.980822
# std        7.348257
# min       23.000000
# 25%       37.000000
# 50%       42.000000
# 75%       46.000000
# max       73.000000
# Name: births, dtype: float64

# %%
df2.describe()
# Out:
#                       date      births
# count                  365  365.000000
# mean   1959-07-02 00:00:00   41.980822
# min    1959-01-01 00:00:00   23.000000
# 25%    1959-04-02 00:00:00   37.000000
# 50%    1959-07-02 00:00:00   42.000000
# 75%    1959-10-01 00:00:00   46.000000
# max    1959-12-31 00:00:00   73.000000
# std                    NaN    7.348257

# %%
df2.head()
# Out:
#         date  births
# 0 1959-01-01      35
# 1 1959-01-02      32
# 2 1959-01-03      30
# 3 1959-01-04      31
# 4 1959-01-05      44

# %%
feature = df2.copy()

# %%
feature['year']=df2['date'].dt.year

# %%
feature['month']=df2['date'].dt.month

# %%
feature['day']=df2['date'].dt.day

# %%
feature.head(5)
# Out:
#         date  births  year  month  day
# 0 1959-01-01      35  1959      1    1
# 1 1959-01-02      32  1959      1    2
# 2 1959-01-03      30  1959      1    3
# 3 1959-01-04      31  1959      1    4
# 4 1959-01-05      44  1959      1    5
